# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# read in joined_gdf
url = "C:/Users/Nissim/Desktop/Vacant Lots Project/vacant-lots-proj/vacancy_guncrime_dash/joined_gdf.geojson"
joined_gdf = gpd.read_file(url).to_crs(epsg=2272)

# import the promise zone shapefile
pz_gdf = gpd.read_file('C:/Users/Nissim/Desktop/Vacant Lots Project/Philadelphia_Promise_Zone.shp').to_crs(epsg=2272)

# clip the joined_gdf to the promise zone
pz_gdf = gpd.clip(joined_gdf, pz_gdf)

# %%
# solution found here: https://www.earthdatascience.org/courses/scientists-guide-to-plotting-data-in-python/plot-spatial-data/customize-vector-plots/python-customize-map-legends-geopandas/

pct_cmap = {
    'Bottom 50%': '#00876c',
    'Top 50%': '#aac872',
    'Top 25%': '#f7e382',
    'Top 10%': '#f5af5c', 
    'Top 5%' : '#ea784d',
    'Top 1%': '#d43d51'
}


# Plot data
fig, ax = plt.subplots(figsize=(10, 10))

# Loop through each attribute type and plot it using the colors assigned in the dictionary
for ctype, data in pz_gdf.groupby('tree_canopy_gap'):
    
    # Define the color for each group using the dictionary
    color = pct_cmap[ctype]
    
    # Plot each group using the color defined above
    data.plot(color=color,
              ax=ax,
              label=ctype)


ax.set(title='Promise Zone Vacant Land by Tree Canopy Gap')
# Place legend in the lower right hand corner of the plot
ax.legend(loc='lower right',
          fontsize=15,
          frameon=True)

ax.set_axis_off()
plt.show()
# Out:
# C:\Users\Nissim\AppData\Local\Temp\ipykernel_46908\2168369860.py:30: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='lower right',
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pz_gdf[(pz_gdf['tree_canopy_gap'] == 'Top 5%') | (pz_gdf['tree_canopy_gap'] == 'Top 1%')]
# Out:
#                   address                  bldg_desc     opa_id  \
# 33409      3631 WARREN ST          ROW 3 STY MASONRY  241046500
# 31418  3801 LANCASTER AVE  STR/OFF+APTS 3STY MASONRY  871402175
# 27555      3712 BARING ST     SEMI/DET 3 STY MASONRY  241165800
# 26936    701-41 N 48TH ST        SCHOOL 3STY MASONRY  783707600
# 17372       800 N 46TH ST      VAC LAND COMM. < ACRE  885088900
# 6440        808 N 46TH ST        VAC LAND RES < ACRE  062373700
# 19648     820 N MARKOE ST        VAC LAND RES < ACRE  062397110
# 33900         820 JUNE ST          ROW 2 STY MASONRY  886810226
# 12101     4646 PARRISH ST        VAC LAND RES < ACRE  062058210
# 21715  4642-44 PARRISH ST        VAC LAND RES < ACRE  062058100
# 12251  4638-40 PARRISH ST      VAC LAND COMM. < ACRE  885068560
# 20949       838 N 46TH ST        VAC LAND RES < ACRE  062375210
# 23408       840 N 46TH ST        VAC LAND RES < ACRE  062375300
# 3810        842 N 46TH ST      VAC LAND COMM. < ACRE  885088940
#
#       councildistrict zipcode      type  \
# 33409               3   19104  Building
# 31418               3   19104  Building
# 27555               3   19104  Building
# 26936               3   19139  Building
# 17372               3   19139       Lot
# 6440                3   19139       Lot
# 19648               3   19139       Lot
# 33900               3   19139  Building
# 12101               3   19139       Lot
# 21715               3   19139       Lot
# 12251               3   19139       Lot
# 20949               3   19139       Lot
# 23408               3   19139       Lot
# 3810                3   19139       Lot
#
#                                                    owner  public_owner  \
# 33409               SOLIMAN AWATI F H/W; SOLIMAN ABDEL A         False
# 31418                                        GOSNELL K B         False
# 27555                                    WM A & ELIZ COX         False
# 26936                           SCHOOL DISTRICT OF PHILA         False
# 17372                                 SOPHIA AND DAD LLC         False
# 6440                           CITY LAND DEVELOPMENT LLC         False
# 19648                     PHILADELPHIA HOUSING AUTHORITY          True
# 33900                     PHILADELPHIA HOUSING AUTHORITY          True
# 12101            REDEVELOPMENT AUTHORITY OF PHILADELPHIA          True
# 21715                         CHURCH; MOUNT HOPE BAPTIST         False
# 12251                         CHURCH; MOUNT HOPE BAPTIST         False
# 20949  CITY OF PHILADELPHIA DEPARTMENT OF PUBLIC PROP...          True
# 23408                                  WARING JONATHAN K         False
# 3810                                   WARING JONATHAN W         False
#
#        comm_partn                                      li_complaints  \
# 33409         NaN                                                NaN
# 31418         NaN  Construction Complaints; Maintenance Complaint...
# 27555         NaN                                                NaN
# 26936         NaN                                                NaN
# 17372         NaN                                                NaN
# 6440          NaN                                                NaN
# 19648         NaN                                                NaN
# 33900         NaN                                                NaN
# 12101         NaN                                                NaN
# 21715         NaN                                                NaN
# 12251         NaN                                                NaN
# 20949         NaN                                                NaN
# 23408         NaN                                                NaN
# 3810          NaN                                                NaN
#
#                                       li_code_violations     neighborhood  \
# 33409                                                NaN  University City
# 31418  INTERIOR DEMOLITION; PARTIAL DEMOLITION; PARTI...         Powelton
# 27555  ID STRUCTURE; ROOF DEFICIENCIES; INTERIOR UNSA...         Powelton
# 26936  EXTERIOR AREA WEEDS; EXIT SIGNS\r\n; PERIODIC ...       Mill Creek
# 17372                                                NaN       Mill Creek
# 6440                                                 NaN       Mill Creek
# 19648                                                NaN       Mill Creek
# 33900                                                NaN       Mill Creek
# 12101                                                NaN       Mill Creek
# 21715                                                NaN       Mill Creek
# 12251                                                NaN       Mill Creek
# 20949                                                NaN       Mill Creek
# 23408                                                NaN       Mill Creek
# 3810                                                 NaN       Mill Creek
#
#                                            relevant_rcos tree_canopy_gap  \
# 33409  Powelton Village Civic Association; P.O. Box 7...          Top 5%
# 31418  Powelton Village Civic Association; P.O. Box 7...          Top 5%
# 27555  Powelton Village Civic Association; P.O. Box 7...          Top 5%
# 26936  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 17372  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 6440   Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 19648  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 33900  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 12101  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 21715  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 12251  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 20949  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 23408  Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
# 3810   Mill Creek Advisory Council; 4700 Brown Street...          Top 5%
#
#       guncrime_density                                           geometry
# 33409       Bottom 50%  POLYGON Z ((2684741.559 238043.584 0.000, 2684...
# 31418       Bottom 50%  POLYGON Z ((2684074.369 238853.625 0.000, 2684...
# 27555       Bottom 50%  POLYGON Z ((2684334.343 238824.771 0.000, 2684...
# 26936       Bottom 50%  POLYGON Z ((2678907.338 240040.254 0.000, 2678...
# 17372       Bottom 50%  POLYGON Z ((2679286.703 240923.654 0.000, 2679...
# 6440        Bottom 50%  POLYGON Z ((2679278.740 240985.813 0.000, 2679...
# 19648       Bottom 50%  POLYGON Z ((2679011.834 241034.152 0.000, 2679...
# 33900       Bottom 50%  POLYGON Z ((2679159.081 241064.294 0.000, 2679...
# 12101       Bottom 50%  POLYGON Z ((2678837.394 241034.522 0.000, 2678...
# 21715       Bottom 50%  POLYGON Z ((2678856.863 241037.557 0.000, 2678...
# 12251       Bottom 50%  POLYGON Z ((2678891.923 241042.047 0.000, 2678...
# 20949       Bottom 50%  POLYGON Z ((2679249.514 241213.949 0.000, 2679...
# 23408       Bottom 50%  POLYGON Z ((2679247.566 241229.158 0.000, 2679...
# 3810        Bottom 50%  POLYGON Z ((2679245.532 241245.028 0.000, 2679...
